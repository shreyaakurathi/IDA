# %%
#LAB3
#SHREYA AKURATHI
#200968188
#25.11.21

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
df = pd.read_excel(r'C:\Users\shrey\Downloads\Cereals1.xls')
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0           100%_Natural_Bran   Q    C       120        3    5      15    2.0
# 1                    All-Bran   K    C        70        4    1     260    9.0
# 2   All-Bran_with_Extra_Fiber   K    C        50        4    0     140   14.0
# 3              Almond_Delight   R    C       110        2    2     200    1.0
# 4     Apple_Cinnamon_Cheerios   G    C       110        2    2     180    1.5
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 71                    Triples   G    C       110        2    1     250    0.0
# 72                       Trix   G    C       110        1    1     140    0.0
# 73                 Wheat_Chex   R    C       100        3    1     230    3.0
# 74                   Wheaties   G    C       100        3    1     200    3.0
# 75        Wheaties_Honey_Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
df.head(10)
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0          100%_Natural_Bran   Q    C       120        3    5      15    2.0
# 1                   All-Bran   K    C        70        4    1     260    9.0
# 2  All-Bran_with_Extra_Fiber   K    C        50        4    0     140   14.0
# 3             Almond_Delight   R    C       110        2    2     200    1.0
# 4    Apple_Cinnamon_Cheerios   G    C       110        2    2     180    1.5
# 5                Apple_Jacks   K    C       110        2    0     125    1.0
# 6                    Basic_4   G    C       130        3    2     210    2.0
# 7                  Bran_Chex   R    C        90        2    1     200    4.0
# 8                Bran_Flakes   P    C        90        3    0     210    5.0
# 9               Cap'n'Crunch   Q    C       120        1    2     220    0.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# ...

# %%
#1)Create a table with the 5-number summary of all the numeric attributes.
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   76.000000  76.000000  76.000000   76.000000  76.000000  76.000000
# mean   107.368421   2.526316   1.013158  160.065789   2.048684  14.723684
# std     19.139378   1.089020   1.013159   84.318813   2.219038   4.160444
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  132.500000   0.750000  12.000000
# 50%    110.000000   2.500000   1.000000  180.000000   1.750000  14.500000
# 75%    110.000000   3.000000   2.000000  212.500000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  76.000000   76.000000   76.000000  76.000000  76.000000  76.000000
# mean    6.934211   93.657895   28.289474   2.197368   1.030000   0.827500
# std     4.473136   68.502565   22.487813   0.832982   0.151438   0.227204
# ...

# %%
#2)For each of the numeric attributes (proteins upto vitamins) , identify and replace all 
# missing data(indicated with -1) with the arithmetic mean of the attribute

df[['protein' , 'fat' , 'sodium', 'fiber' , 'carbo' , 'sugars' , 'potass' , 'vitamins']][df.values==-1]
# Out:
#     protein  fat  sodium  fiber  carbo  sugars  potass  vitamins
# 3         2    2     200    1.0   14.0       8      -1        25
# 19        3    0      80    1.0   21.0       0      -1         0
# 56        5    2       0    2.7   -1.0      -1     110         0
# 56        5    2       0    2.7   -1.0      -1     110         0

# %%
for c in df.columns:

    if(c== 'protein' or c=='fat' or c== 'sodium' or c== 'fiber' or c== 'carbo' or c== 'sugars' or c=='potass' or c== 'vitamins'):

        mean_val = df[c].mean()

        df[c].replace(to_replace=-1, value=mean_val, inplace=True)
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0           100%_Natural_Bran   Q    C       120        3    5      15    2.0
# 1                    All-Bran   K    C        70        4    1     260    9.0
# 2   All-Bran_with_Extra_Fiber   K    C        50        4    0     140   14.0
# 3              Almond_Delight   R    C       110        2    2     200    1.0
# 4     Apple_Cinnamon_Cheerios   G    C       110        2    2     180    1.5
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 71                    Triples   G    C       110        2    1     250    0.0
# 72                       Trix   G    C       110        1    1     140    0.0
# 73                 Wheat_Chex   R    C       100        3    1     230    3.0
# 74                   Wheaties   G    C       100        3    1     200    3.0
# 75        Wheaties_Honey_Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
#3)Create a table with the 5-number summary of all the numeric attributes after treating 
#missing values. Do you think the strategy used in dealing with missing values was 
#effective?

df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   76.000000  76.000000  76.000000   76.000000  76.000000  76.000000
# mean   107.368421   2.526316   1.013158  160.065789   2.048684  14.930575
# std     19.139378   1.089020   1.013159   84.318813   2.219038   3.737575
# min     50.000000   1.000000   0.000000    0.000000   0.000000   7.000000
# 25%    100.000000   2.000000   0.000000  132.500000   0.750000  12.000000
# 50%    110.000000   2.500000   1.000000  180.000000   1.750000  14.861842
# 75%    110.000000   3.000000   2.000000  212.500000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  76.000000   76.000000   76.000000  76.000000  76.000000  76.000000
# mean    7.038608   96.148892   28.289474   2.197368   1.030000   0.827500
# std     4.377048   66.688658   22.487813   0.832982   0.151438   0.227204
# ...

# %%
print("Yes.The strategy used for dealing with noisy data was effective as the values of the the central tendencies/and std. deviation changed significantly")
# Out:
# Yes.The strategy used for dealing with noisy data was effective as the values of the the central tendencies/and std. deviation changed significantly

# %%
#4)For each of the numeric attributes (proteins upto vitamins), identify and replace all 
#noisy data with the median of attribute.

df1 = df[['protein' , 'fat' , 'sodium' , 'fiber' , 'carbo' , 'sugars' , 'potass' , 'vitamins']]
df1.plot.box()
# Out:
# <AxesSubplot:>

# %%
m=df1.describe().T
m
# Out:
#           count        mean        std   min     25%         50%    75%    max
# protein    76.0    2.526316   1.089020   1.0    2.00    2.500000    3.0    6.0
# fat        76.0    1.013158   1.013159   0.0    0.00    1.000000    2.0    5.0
# sodium     76.0  160.065789  84.318813   0.0  132.50  180.000000  212.5  320.0
# fiber      76.0    2.048684   2.219038   0.0    0.75    1.750000    3.0   14.0
# carbo      76.0   14.930575   3.737575   7.0   12.00   14.861842   17.0   23.0
# sugars     76.0    7.038608   4.377048   0.0    3.00    7.000000   11.0   15.0
# potass     76.0   96.148892  66.688658  15.0   43.75   90.000000  120.0  330.0
# vitamins   76.0   28.289474  22.487813   0.0   25.00   25.000000   25.0  100.0

# %%
m["IQR"]=m['75%']-m['25%']
m
m['Lowerbound']=m['25%'] - m['IQR']*1.5
m['Upperbound']=m['IQR']*1.5 + m['75%']
m
# Out:
#           count        mean        std   min     25%         50%    75%  \
# protein    76.0    2.526316   1.089020   1.0    2.00    2.500000    3.0
# fat        76.0    1.013158   1.013159   0.0    0.00    1.000000    2.0
# sodium     76.0  160.065789  84.318813   0.0  132.50  180.000000  212.5
# fiber      76.0    2.048684   2.219038   0.0    0.75    1.750000    3.0
# carbo      76.0   14.930575   3.737575   7.0   12.00   14.861842   17.0
# sugars     76.0    7.038608   4.377048   0.0    3.00    7.000000   11.0
# potass     76.0   96.148892  66.688658  15.0   43.75   90.000000  120.0
# vitamins   76.0   28.289474  22.487813   0.0   25.00   25.000000   25.0
#
#             max    IQR  Lowerbound  Upperbound
# protein     6.0   1.00       0.500       4.500
# fat         5.0   2.00      -3.000       5.000
# sodium    320.0  80.00      12.500     332.500
# fiber      14.0   2.25      -2.625       6.375
# carbo      23.0   5.00       4.500      24.500
# ...

# %%
df2=m.T
df2
# Out:
#               protein        fat      sodium      fiber      carbo     sugars  \
# count       76.000000  76.000000   76.000000  76.000000  76.000000  76.000000
# mean         2.526316   1.013158  160.065789   2.048684  14.930575   7.038608
# std          1.089020   1.013159   84.318813   2.219038   3.737575   4.377048
# min          1.000000   0.000000    0.000000   0.000000   7.000000   0.000000
# 25%          2.000000   0.000000  132.500000   0.750000  12.000000   3.000000
# 50%          2.500000   1.000000  180.000000   1.750000  14.861842   7.000000
# 75%          3.000000   2.000000  212.500000   3.000000  17.000000  11.000000
# max          6.000000   5.000000  320.000000  14.000000  23.000000  15.000000
# IQR          1.000000   2.000000   80.000000   2.250000   5.000000   8.000000
# Lowerbound   0.500000  -3.000000   12.500000  -2.625000   4.500000  -9.000000
# Upperbound   4.500000   5.000000  332.500000   6.375000  24.500000  23.000000
#
# ...

# %%
df2["protein"] = df2["protein"].mask(df2["protein"] >4.5, df2["protein"].median())
df2["sodium"] = df2["sodium"].mask(df2["sodium"] <12.5, df2["sodium"].median())

df2["fiber"] = df2["fiber"].mask(df2["fiber"] >6.37, df2["fiber"].median())

df2["potass"] = df2["potass"].mask(df2["potass"] >234.375, df2["potass"].median())

df2["vitamins"] = df2["vitamins"].mask(df2["vitamins"] >25, df2["vitamins"].median())

# %%
df2.boxplot()
# Out:
# <AxesSubplot:>

# %%
#5) Create a table with the 5-number summary of all the numeric attributes after treating 
#noisy values. Do you think the strategy used in dealing with noisy values was 
#effective?

df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   76.000000  76.000000  76.000000   76.000000  76.000000  76.000000
# mean   107.368421   2.526316   1.013158  160.065789   2.048684  14.930575
# std     19.139378   1.089020   1.013159   84.318813   2.219038   3.737575
# min     50.000000   1.000000   0.000000    0.000000   0.000000   7.000000
# 25%    100.000000   2.000000   0.000000  132.500000   0.750000  12.000000
# 50%    110.000000   2.500000   1.000000  180.000000   1.750000  14.861842
# 75%    110.000000   3.000000   2.000000  212.500000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  76.000000   76.000000   76.000000  76.000000  76.000000  76.000000
# mean    7.038608   96.148892   28.289474   2.197368   1.030000   0.827500
# std     4.377048   66.688658   22.487813   0.832982   0.151438   0.227204
# ...

# %%
print("The strategy used in dealing with the noisy data was somewhat effective to an extent as it reduced the number of noisy data in the dataset but didnt completely remove them.")
# Out:
# The strategy used in dealing with the noisy data was somewhat effective to an extent as it reduced the number of noisy data in the dataset but didnt completely remove them.

# %%
#6) Cross tabulate the type of cereal (hot vs cold) against the manufacturer

pd.crosstab(df['mfr'],df['type'])
# Out:
# type   C  H
# mfr
# A      0  1
# G     22  0
# K     23  0
# N      4  1
# P      9  0
# Q      7  1
# R      8  0

# %%
#7) Which is the cereal with the best rating, worst rating?

print("Best rating:")
df[df['rating']==df['rating'].max()]
# Out:
# Best rating:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 2  All-Bran_with_Extra_Fiber   K    C        50        4    0     140   14.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 2    8.0     0.0   330.0        25      3     1.0   0.5  93.704912

# %%
print('Worst Rating:')
df[df['rating']==df['rating'].min()]
# Out:
# Worst Rating:
#            name mfr type  calories  protein  fat  sodium  fiber  carbo  \
# 9  Cap'n'Crunch   Q    C       120        1    2     220    0.0   12.0
#
#    sugars  potass  vitamins  shelf  weight  cups     rating
# 9    12.0    35.0        25      2     1.0  0.75  18.042851

# %%
#8) Plot a side-by-side boxplot comparing the consumer rating of hot vs. cold cereals.
sns.boxplot(y=df['rating'],x=df['type'], color='salmon')
# Out:
# <AxesSubplot:xlabel='type', ylabel='rating'>

# %%
#9) Is there a relation between sugars, calories, carbs, and fat?
cor= df[['sugars' , 'calories' , 'carbo' , 'fat']]
c=cor.corr()
sns.heatmap(c, annot=True)
# Out:
# <AxesSubplot:>

# %%
#10) Which manufacturers produce cereal with highest calories?

df[df['calories']==df['calories'].max()]
# Out:
#                     name mfr type  calories  protein  fat  sodium  fiber  \
# 45  Mueslix_Crispy_Blend   K    C       160        3    2     150    3.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 45   17.0    13.0   160.0        25      3     1.5  0.67  30.313351

# %%
#11) Use correlation tests and visualization to identify if the two variables calories and 
#consumer rating associated ?
correlation = df[['calories' , 'rating']].corr()
correlation
# Out:
#           calories    rating
# calories  1.000000 -0.674336
# rating   -0.674336  1.000000

# %%
sns.heatmap(correlation,annot=True)
# Out:
# <AxesSubplot:>

# %%
#12) Use correlation tests and visualization to identify if the two variables shelf and 
#calories associated? 

contigency= pd.crosstab(df['shelf'],df['calories'],normalize='index')
contigency
# Out:
# calories       50        70    80        90        100       110       120  \
# shelf
# 1         0.000000  0.000000  0.05  0.150000  0.300000  0.500000  0.000000
# 2         0.000000  0.000000  0.00  0.047619  0.190476  0.523810  0.238095
# 3         0.085714  0.028571  0.00  0.085714  0.200000  0.228571  0.142857
#
# calories       130       140       150       160
# shelf
# 1         0.000000  0.000000  0.000000  0.000000
# 2         0.000000  0.000000  0.000000  0.000000
# 3         0.057143  0.085714  0.057143  0.028571

# %%
sns.heatmap(contigency, annot=True,)
# Out:
# <AxesSubplot:xlabel='calories', ylabel='shelf'>

# %%
c, p, dof, expected = stats.chi2_contingency(contigency)
print("p:",p)
# Out:
# p: 0.9999999987838062

# %%
#13) Is there a relation between manufacturer and rating?
sns.barplot(x=df['mfr'],y=df['rating'])
plt.show()

# %%
#14) Which nutrients are essential for a good rating for a cereal?

variety5=['calories','protein','fat','sodium','fiber','carbo','sugars','potass','vitamins','rating']
df8=df[variety5][df['rating']>50.7]
df8.corr(method='pearson')
# Out:
#           calories   protein       fat    sodium     fiber     carbo  \
# calories  1.000000  0.480686  0.329097  0.260754 -0.398579  0.672810
# protein   0.480686  1.000000  0.598256  0.567629  0.153189  0.022728
# fat       0.329097  0.598256  1.000000  0.306848 -0.045681 -0.048001
# sodium    0.260754  0.567629  0.306848  1.000000  0.324466 -0.152710
# fiber    -0.398579  0.153189 -0.045681  0.324466  1.000000 -0.587833
# carbo     0.672810  0.022728 -0.048001 -0.152710 -0.587833  1.000000
# sugars    0.398748  0.146061  0.300515  0.063277  0.001711 -0.215433
# potass   -0.300981  0.245369  0.081571  0.368679  0.932480 -0.562263
# vitamins  0.332095  0.311999  0.126428  0.599013  0.280307 -0.241774
# rating   -0.595256 -0.188169 -0.461869 -0.267855  0.620996 -0.187992
#
#             sugars    potass  vitamins    rating
# calories  0.398748 -0.300981  0.332095 -0.595256
# protein   0.146061  0.245369  0.311999 -0.188169
# fat       0.300515  0.081571  0.126428 -0.461869
# ...

# %%
#15)Design a Linear regression model to predict the rating of a cereal based on top 3 related nutrients. Tabulate the accuracy of the model using a 70 ,30 split.

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import sklearn.metrics as metrics

# %%
x = df[['fiber', 'calories', 'sugars']]
y = df['rating']
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.7, 
                                                    test_size = 0.3, random_state = 100)
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train, y_train)
reg.predict(x_test)
print("Linear Regression Model Between Fiber, Calories, Sugars and Rating")
reg.score(x_test, y_test)
# Out:
# Linear Regression Model Between Fiber, Calories, Sugars and Rating
# 0.7684073959308149
